# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
d1=pd.read_csv('covid_19_india.csv')

# %%
d1
# Out:
#        Sno      Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 0        1  30/01/20  6:00 PM               Kerala                       1
# 1        2  31/01/20  6:00 PM               Kerala                       1
# 2        3  01/02/20  6:00 PM               Kerala                       2
# 3        4  02/02/20  6:00 PM               Kerala                       3
# 4        5  03/02/20  6:00 PM               Kerala                       3
# ...    ...       ...      ...                  ...                     ...
# 4316  4317  20/07/20  8:00 AM            Telangana                       -
# 4317  4318  20/07/20  8:00 AM              Tripura                       -
# 4318  4319  20/07/20  8:00 AM          Uttarakhand                       -
# 4319  4320  20/07/20  8:00 AM        Uttar Pradesh                       -
# 4320  4321  20/07/20  8:00 AM          West Bengal                       -
#
#      ConfirmedForeignNational  Cured  Deaths  Confirmed
# ...

# %%
d2=pd.read_csv('Individualdetails.csv')

# %%
d2
# Out:
#           id government_id diagnosed_date  age gender  \
# 0          0      KL-TS-P1     30/01/2020   20      F
# 1          1      KL-AL-P1     02/02/2020  NaN    NaN
# 2          2      KL-KS-P1     03/02/2020  NaN    NaN
# 3          3         DL-P1     02/03/2020   45      M
# 4          4         TS-P1     02/03/2020   24      M
# ...      ...           ...            ...  ...    ...
# 28177  28178           NaN     22/04/2020  NaN    NaN
# 28178  28179           NaN     24/04/2020  NaN    NaN
# 28179  28180           NaN     24/04/2020  NaN    NaN
# 28180  28181           NaN     25/04/2020  NaN    NaN
# 28181  28182           NaN     25/04/2020  NaN    NaN
#
#                   detected_city detected_district detected_state nationality  \
# 0                      Thrissur          Thrissur         Kerala       India
# 1                     Alappuzha         Alappuzha         Kerala       India
# 2                     Kasaragod         Kasaragod         Kerala       India
# ...

# %%
d3=pd.read_csv('population_india_census2011.csv')

# %%
d3
# Out:
#     Sno                   State / Union Territory  Population  \
# 0     1                             Uttar Pradesh   199812341
# 1     2                               Maharashtra   112374333
# 2     3                                     Bihar   104099452
# 3     4                               West Bengal    91276115
# 4     5                            Madhya Pradesh    72626809
# 5     6                                Tamil Nadu    72147030
# 6     7                                 Rajasthan    68548437
# 7     8                                 Karnataka    61095297
# 8     9                                   Gujarat    60439692
# 9    10                            Andhra Pradesh    49577103
# 10   11                                    Odisha    41974218
# 11   12                                 Telengana    35003674
# 12   13                                    Kerala    33406061
# 13   14                                 Jharkhand    32988134
# ...

# %%
d1['State/UnionTerritory'].unique()
# Out:
# array(['Kerala', 'Telengana', 'Delhi', 'Rajasthan', 'Uttar Pradesh',
#        'Haryana', 'Ladakh', 'Tamil Nadu', 'Karnataka', 'Maharashtra',
#        'Punjab', 'Jammu and Kashmir', 'Andhra Pradesh', 'Uttarakhand',
#        'Odisha', 'Puducherry', 'West Bengal', 'Chhattisgarh',
#        'Chandigarh', 'Gujarat', 'Himachal Pradesh', 'Madhya Pradesh',
#        'Bihar', 'Manipur', 'Mizoram', 'Andaman and Nicobar Islands',
#        'Goa', 'Unassigned', 'Assam', 'Jharkhand', 'Arunachal Pradesh',
#        'Tripura', 'Nagaland', 'Meghalaya', 'Dadar Nagar Haveli',
#        'Cases being reassigned to states', 'Sikkim', 'Daman & Diu',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Telangana'],
#       dtype=object)

# %%
latest=d1[d1['Date']=='20/07/20']

# %%
latest
# Out:
#        Sno      Date     Time                      State/UnionTerritory  \
# 4286  4287  20/07/20  8:00 AM               Andaman and Nicobar Islands
# 4287  4288  20/07/20  8:00 AM                            Andhra Pradesh
# 4288  4289  20/07/20  8:00 AM                         Arunachal Pradesh
# 4289  4290  20/07/20  8:00 AM                                     Assam
# 4290  4291  20/07/20  8:00 AM                                     Bihar
# 4291  4292  20/07/20  8:00 AM                                Chandigarh
# 4292  4293  20/07/20  8:00 AM                              Chhattisgarh
# 4293  4294  20/07/20  8:00 AM  Dadra and Nagar Haveli and Daman and Diu
# 4294  4295  20/07/20  8:00 AM                                     Delhi
# 4295  4296  20/07/20  8:00 AM                                       Goa
# 4296  4297  20/07/20  8:00 AM                                   Gujarat
# 4297  4298  20/07/20  8:00 AM                                   Haryana
# ...

# %%
#total number of cases
d1['Confirmed'].sum()
# Out:
# 30385317

# %%
plt.figure(figsize=(16, 6))
sns.barplot(latest['State/UnionTerritory'][0:7], latest['Confirmed'][0:7])
# Out:
# <AxesSubplot:xlabel='State/UnionTerritory', ylabel='Confirmed'>

# %%
plt.figure(figsize=(16, 6))
sns.barplot(latest['State/UnionTerritory'][7:13], latest['Confirmed'][7:13])
# Out:
# <AxesSubplot:xlabel='State/UnionTerritory', ylabel='Confirmed'>

# %%
plt.figure(figsize=(16, 6))
sns.barplot(latest['State/UnionTerritory'][13:25], latest['Confirmed'][13:25])
# Out:
# <AxesSubplot:xlabel='State/UnionTerritory', ylabel='Confirmed'>

# %%
plt.figure(figsize=(16, 6))
sns.barplot(latest['State/UnionTerritory'][25:35], latest['Confirmed'][25:35])
# Out:
# <AxesSubplot:xlabel='State/UnionTerritory', ylabel='Confirmed'>

# %%
plt.figure(figsize=(16, 6))
sns.barplot(latest['State/UnionTerritory'][0:7], latest['Deaths'][0:7])
# Out:
# <AxesSubplot:xlabel='State/UnionTerritory', ylabel='Deaths'>

# %%
plt.figure(figsize=(16, 6))
sns.barplot(latest['State/UnionTerritory'][7:13], latest['Deaths'][7:13])
# Out:
# <AxesSubplot:xlabel='State/UnionTerritory', ylabel='Deaths'>

# %%
plt.figure(figsize=(16, 6))
sns.barplot(latest['State/UnionTerritory'][13:25], latest['Deaths'][13:25])
# Out:
# <AxesSubplot:xlabel='State/UnionTerritory', ylabel='Deaths'>

# %%
plt.figure(figsize=(16, 6))
sns.barplot(latest['State/UnionTerritory'][25:35], latest['Deaths'][25:35])
# Out:
# <AxesSubplot:xlabel='State/UnionTerritory', ylabel='Deaths'>

# %%
ag=pd.read_csv('AgeGroupDetails.csv')

# %%
ag
# Out:
#    Sno AgeGroup  TotalCases Percentage
# 0    1      0-9          22      3.18%
# 1    2    10-19          27      3.90%
# 2    3    20-29         172     24.86%
# 3    4    30-39         146     21.10%
# 4    5    40-49         112     16.18%
# 5    6    50-59          77     11.13%
# 6    7    60-69          89     12.86%
# 7    8    70-79          28      4.05%
# 8    9     >=80          10      1.45%
# 9   10  Missing           9      1.30%

# %%
ag['value']=ag['Percentage'].apply(lambda perc:perc.split('%')[0])

# %%
plt.figure(figsize=(16, 6))
sns.barplot(ag['AgeGroup'],ag['value'])
plt.ylabel("percentage")
# Out:
# Text(0, 0.5, 'percentage')

# %%
#current status of covid victim

# %%
d2['current_status'].unique()
# Out:
# array(['Recovered', 'Hospitalized', 'Deceased', 'Migrated'], dtype=object)

# %%
plt.figure(figsize=(50, 10))
sns.countplot(x='detected_state', data=d2, hue='current_status')
#zoom in to take a view
# Out:
# <AxesSubplot:xlabel='detected_state', ylabel='count'>

# %%
d1['month']=d1['Date'].apply(lambda x: int(x.split('/')[1]))

# %%
dmap={1:'jan',2:'feb',3:'mar',4:'apr',5:'may',6:'jun',7:'jul',8:'aug',9:'sep',10:'oct',11:'nov',12:'dec'}

# %%
d1['month']=d1['month'].map(dmap)

# %%
d1
# Out:
#        Sno      Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 0        1  30/01/20  6:00 PM               Kerala                       1
# 1        2  31/01/20  6:00 PM               Kerala                       1
# 2        3  01/02/20  6:00 PM               Kerala                       2
# 3        4  02/02/20  6:00 PM               Kerala                       3
# 4        5  03/02/20  6:00 PM               Kerala                       3
# ...    ...       ...      ...                  ...                     ...
# 4316  4317  20/07/20  8:00 AM            Telangana                       -
# 4317  4318  20/07/20  8:00 AM              Tripura                       -
# 4318  4319  20/07/20  8:00 AM          Uttarakhand                       -
# 4319  4320  20/07/20  8:00 AM        Uttar Pradesh                       -
# 4320  4321  20/07/20  8:00 AM          West Bengal                       -
#
#      ConfirmedForeignNational  Cured  Deaths  Confirmed month
# ...

# %%
newl=latest
x=newl.drop(['Sno','ConfirmedIndianNational','ConfirmedForeignNational'],axis=1)
x
# Out:
#           Date     Time                      State/UnionTerritory   Cured  \
# 4286  20/07/20  8:00 AM               Andaman and Nicobar Islands     145
# 4287  20/07/20  8:00 AM                            Andhra Pradesh   22890
# 4288  20/07/20  8:00 AM                         Arunachal Pradesh     282
# 4289  20/07/20  8:00 AM                                     Assam   16023
# 4290  20/07/20  8:00 AM                                     Bihar   16308
# 4291  20/07/20  8:00 AM                                Chandigarh     488
# 4292  20/07/20  8:00 AM                              Chhattisgarh    3775
# 4293  20/07/20  8:00 AM  Dadra and Nagar Haveli and Daman and Diu     414
# 4294  20/07/20  8:00 AM                                     Delhi  103134
# 4295  20/07/20  8:00 AM                                       Goa    2218
# 4296  20/07/20  8:00 AM                                   Gujarat   34901
# 4297  20/07/20  8:00 AM                                   Haryana   19793
# ...

# %%
sns.heatmap(x.corr(),cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
d2.fillna('unknown')
# Out:
#           id government_id diagnosed_date      age   gender  \
# 0          0      KL-TS-P1     30/01/2020       20        F
# 1          1      KL-AL-P1     02/02/2020  unknown  unknown
# 2          2      KL-KS-P1     03/02/2020  unknown  unknown
# 3          3         DL-P1     02/03/2020       45        M
# 4          4         TS-P1     02/03/2020       24        M
# ...      ...           ...            ...      ...      ...
# 28177  28178       unknown     22/04/2020  unknown  unknown
# 28178  28179       unknown     24/04/2020  unknown  unknown
# 28179  28180       unknown     24/04/2020  unknown  unknown
# 28180  28181       unknown     25/04/2020  unknown  unknown
# 28181  28182       unknown     25/04/2020  unknown  unknown
#
#                   detected_city detected_district detected_state nationality  \
# 0                      Thrissur          Thrissur         Kerala       India
# 1                     Alappuzha         Alappuzha         Kerala       India
# ...

# %%
plt.figure(figsize=(10,6), dpi=80)
sns.countplot(x='gender' , data=d2)
plt.ylabel('Count', size=12)
plt.title('Count on the basis of gender', size=16)
# Out:
# Text(0.5, 1.0, 'Count on the basis of gender')

# %%
d1
# Out:
#        Sno      Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 0        1  30/01/20  6:00 PM               Kerala                       1
# 1        2  31/01/20  6:00 PM               Kerala                       1
# 2        3  01/02/20  6:00 PM               Kerala                       2
# 3        4  02/02/20  6:00 PM               Kerala                       3
# 4        5  03/02/20  6:00 PM               Kerala                       3
# ...    ...       ...      ...                  ...                     ...
# 4316  4317  20/07/20  8:00 AM            Telangana                       -
# 4317  4318  20/07/20  8:00 AM              Tripura                       -
# 4318  4319  20/07/20  8:00 AM          Uttarakhand                       -
# 4319  4320  20/07/20  8:00 AM        Uttar Pradesh                       -
# 4320  4321  20/07/20  8:00 AM          West Bengal                       -
#
# ...

# %%
d1['count']=d1['Confirmed'].cumsum()

# %%
from plotly import __version__

# %%
import cufflinks as cf

# %%
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
plt.figure(figsize=(55,55), dpi=80)
d1.iplot(kind='bar',x='Date',y='count')
# Out:
# <div>
#
#
#             <div id="78f927ff-8bac-43ae-ba91-1214b7f7dc67" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("78f927ff-8bac-43ae-ba91-1214b7f7dc67")) {
#                     Plotly.newPlot(
#                         '78f927ff-8bac-43ae-ba91-1214b7f7dc67',
# ...

# %%
d1['dcount'].head(1200)
# Out:
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
#         ...
# 1195    5927
# 1196    5927
# 1197    5974
# 1198    5974
# 1199    6069
# Name: dcount, Length: 1200, dtype: int64

# %%
stw=pd.read_csv('StatewiseTestingDetails.csv')

# %%
stw
# Out:
#             Date                        State  TotalSamples Negative  Positive
# 0     2020-04-17  Andaman and Nicobar Islands        1403.0     1210      12.0
# 1     2020-04-24  Andaman and Nicobar Islands        2679.0      NaN      27.0
# 2     2020-04-27  Andaman and Nicobar Islands        2848.0      NaN      33.0
# 3     2020-05-01  Andaman and Nicobar Islands        3754.0      NaN      33.0
# 4     2020-05-16  Andaman and Nicobar Islands        6677.0      NaN      33.0
# ...          ...                          ...           ...      ...       ...
# 3252  2020-07-15                  West Bengal      649928.0      NaN   34427.0
# 3253  2020-07-16                  West Bengal      663108.0      NaN   36117.0
# 3254  2020-07-17                  West Bengal      676348.0      NaN   38011.0
# 3255  2020-07-18                  West Bengal      689813.0      NaN   40209.0
# 3256  2020-07-19                  West Bengal      703284.0      NaN   42487.0
#
# [3257 rows x 5 columns]

# %%
stw['Date'].nunique()
# Out:
# 110

# %%
stw.fillna('unknown')
# Out:
#             Date                        State  TotalSamples Negative Positive
# 0     2020-04-17  Andaman and Nicobar Islands        1403.0     1210       12
# 1     2020-04-24  Andaman and Nicobar Islands        2679.0  unknown       27
# 2     2020-04-27  Andaman and Nicobar Islands        2848.0  unknown       33
# 3     2020-05-01  Andaman and Nicobar Islands        3754.0  unknown       33
# 4     2020-05-16  Andaman and Nicobar Islands        6677.0  unknown       33
# ...          ...                          ...           ...      ...      ...
# 3252  2020-07-15                  West Bengal      649928.0  unknown    34427
# 3253  2020-07-16                  West Bengal      663108.0  unknown    36117
# 3254  2020-07-17                  West Bengal      676348.0  unknown    38011
# 3255  2020-07-18                  West Bengal      689813.0  unknown    40209
# 3256  2020-07-19                  West Bengal      703284.0  unknown    42487
#
# [3257 rows x 5 columns]

# %%
x=stw[['State','Positive','Date']]

# %%
x
# Out:
#                             State  Positive        Date
# 0     Andaman and Nicobar Islands      12.0  2020-04-17
# 1     Andaman and Nicobar Islands      27.0  2020-04-24
# 2     Andaman and Nicobar Islands      33.0  2020-04-27
# 3     Andaman and Nicobar Islands      33.0  2020-05-01
# 4     Andaman and Nicobar Islands      33.0  2020-05-16
# ...                           ...       ...         ...
# 3252                  West Bengal   34427.0  2020-07-15
# 3253                  West Bengal   36117.0  2020-07-16
# 3254                  West Bengal   38011.0  2020-07-17
# 3255                  West Bengal   40209.0  2020-07-18
# 3256                  West Bengal   42487.0  2020-07-19
#
# [3257 rows x 3 columns]

# %%
xlatest=x[x['Date']=='2020-07-19']
xlatest
# Out:
#                   State  Positive        Date
# 164      Andhra Pradesh   49650.0  2020-07-19
# 255   Arunachal Pradesh     740.0  2020-07-19
# 337               Assam   22981.0  2020-07-19
# 439               Bihar   26379.0  2020-07-19
# 540          Chandigarh     717.0  2020-07-19
# 635        Chhattisgarh    5407.0  2020-07-19
# 816               Delhi  122793.0  2020-07-19
# 912                 Goa    3657.0  2020-07-19
# 1014            Gujarat   48441.0  2020-07-19
# 1119            Haryana   26164.0  2020-07-19
# 1220   Himachal Pradesh    1521.0  2020-07-19
# 1322  Jammu and Kashmir   13899.0  2020-07-19
# 1420          Jharkhand    5552.0  2020-07-19
# 1525          Karnataka   63772.0  2020-07-19
# 1635             Kerala   12481.0  2020-07-19
# 1697             Ladakh    1178.0  2020-07-19
# 1802     Madhya Pradesh   22600.0  2020-07-19
# 1906        Maharashtra  315387.0  2020-07-19
# 1963            Manipur    1911.0  2020-07-19
# ...

# %%
xlatest[['State','Positive']].scatter_matrix()
#check on plot.ly(export to plot.py)
# Out:
# <div>
#
#
#             <div id="bc4de4eb-b5ff-4ce3-8f69-62543a175263" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("bc4de4eb-b5ff-4ce3-8f69-62543a175263")) {
#                     Plotly.newPlot(
#                         'bc4de4eb-b5ff-4ce3-8f69-62543a175263',
# ...

# %%
hos=pd.read_csv('HospitalBedsIndia.csv')
hos.drop(['Sno'],axis=1,inplace=True)
hos
# Out:
#                      State/UT NumPrimaryHealthCenters_HMIS  \
# 0   Andaman & Nicobar Islands                           27
# 1              Andhra Pradesh                         1417
# 2           Arunachal Pradesh                          122
# 3                       Assam                         1007
# 4                       Bihar                         2007
# 5                  Chandigarh                           40
# 6                Chhattisgarh                          813
# 7        Dadra & Nagar Haveli                            9
# 8                 Daman & Diu                            4
# 9                       Delhi                          534
# 10                        Goa                           31
# 11                    Gujarat                         1770
# 12                    Haryana                          500
# 13           Himachal Pradesh                          516
# 14            Jammu & Kashmir                          702
# ...

# %%
f=plt.figure(figsize=(15,15))
sns.heatmap(hos.corr(),cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
#this data and scheme is derived
df = pd.read_csv('https://raw.githubusercontent.com/datasets/covid-19/master/data/countries-aggregated.csv', parse_dates=['Date'])
countries = ['Canada', 'Germany', 'United Kingdom', 'US', 'France', 'India']
df = df[df['Country'].isin(countries)]


df['Cases'] = df[['Confirmed', 'Recovered', 'Deaths']].sum(axis=1)

# %%
import matplotlib.ticker as ticker

# %%
df = df.pivot(index='Date', columns='Country', values='Cases')
countries = list(df.columns)
covid = df.reset_index('Date')
covid.set_index(['Date'], inplace=True)
covid.columns = countries

# %%
populations = {'Canada':37664517, 'Germany': 83721496 , 'United Kingdom': 67802690 , 'US': 330548815, 'France': 65239883, 'India':1380004385}
percapita = covid.copy()
for country in list(percapita.columns):
    percapita[country] = percapita[country]/populations[country]*100000

# %%
colors = {'Canada':'#045275', 'India':'#089099', 'France':'#7CCBA2', 'Germany':'#FCDE9C', 'US':'#DC3977', 'United Kingdom':'#7C1D6F'}
plt.style.use('fivethirtyeight')


plot = covid.plot(figsize=(12,8), color=list(colors.values()), linewidth=5, legend=False)
plot.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plot.grid(color='#d4d4d4')
plot.set_xlabel('Date')
plot.set_ylabel('# of Cases')


for country in list(colors.keys()):
    plot.text(x = covid.index[-1], y = covid[country].max(), color = colors[country], s = country, weight = 'bold')

plot.text(x = covid.index[1], y = int(covid.max().max())+15000, s = "For the USA, India, Germany, France, United Kingdom, and Canada\nIncludes Current Cases, Recoveries, and Deaths", fontsize = 16, alpha = .75)
plot.text(x = percapita.index[1], y = -100000,s = 'datagy.io                      Source: https://github.com/datasets/covid-19/blob/master/data/countries-aggregated.csv', fontsize = 10)
plt.title('Covid-19 cases worldwide')
# Out:
# Text(0.5, 1.0, 'Covid-19 cases worldwide')

# %%
df = pd.read_csv('covid_19_india.csv', parse_dates=['Date'], dayfirst=True)           # READ OUR CSV FILE(PATH MUST BE SPECIFIED)

# %%
df['Date']= pd.to_datetime(df['Date'])          # Date is converted to DateTime format.
df = df[df['Date'].dt.year==2020]

# %%
df = df.drop(['Sno','ConfirmedForeignNational','ConfirmedIndianNational','Time'],axis=1)

# %%
df.columns = ['date','state','discharged','deaths','confirmed']

# %%
df['month']=df['date'].dt.month                    # Month is accessed from the DateTime object.

# %%
df_confirm_m= df['confirmed'].groupby(df['month']).sum()
df_dis_m= df['discharged'].groupby(df['month']).sum()      # creating instances for 'confirmed','deaths','discharged' by month column
df_death_m= df['deaths'].groupby(df['month']).sum()

# %%
df1 = df_confirm_m.sum()
df2 = df_dis_m.sum()
df3 = df_death_m.sum()
df1= pd.DataFrame(df_confirm_m)                         # The total counts of our cases are taken and made as 3 DataFrames.
df2= pd.DataFrame(df_dis_m)
df3= pd.DataFrame(df_death_m)

# %%
cols=[df1,df2,df3]
df.total=pd.concat(cols,axis=1)
# Out:
# C:\Users\CHAKRA~1\AppData\Local\Temp/ipykernel_2576/1691807105.py:2: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.total=pd.concat(cols,axis=1)

# %%
df.total['discharge_rate'] = df.total['discharged']/df.total['confirmed']      # create instances for 'death_rate and discharge_rate'
df.total['death_rate'] = df.total['deaths']/df.total['confirmed']

# %%
df.total.replace(np.inf,0,inplace=True)                                   # infinite values are replaced by -0

# %%
df.total.reset_index(inplace=True)

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='month',y='confirmed',data=df.total)
# Out:
# <AxesSubplot:xlabel='month', ylabel='confirmed'>

# %%
plt.figure(figsize=(12,6))
sns.lineplot(x="month",y="discharged",data=df.total,color="g",lw=3,marker='o',markersize=10)
plt.title('DISCHARGE RATE PER MONTH')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.lineplot(x="month",y="deaths",data=df.total,color="r",lw=3,marker='o',markersize=10)
plt.title('DEATH RATE PER MONTH')
plt.show()

# %%
df.head()
# Out:
#         date   state  discharged  deaths  confirmed  month
# 0 2020-01-30  Kerala           0       0          1      1
# 1 2020-01-31  Kerala           0       0          1      1
# 2 2020-02-01  Kerala           0       0          2      2
# 3 2020-02-02  Kerala           0       0          3      2
# 4 2020-02-03  Kerala           0       0          3      2
